# %%
import pandas as pd

df = pd.read_csv("Mall_Customers.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("Mall_Customers.csv")
#       4
#       5 df.head()
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Mall_Customers.csv")

df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    str
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# CustomerID                int64
# Genre                       str
# Age                       int64
# Annual Income (k$)        int64
# Spending Score (1-100)    int64
# dtype: object

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Female    112
# Male       88
# Name: count, dtype: int64

# %%
#Customer Gender Distibution Graph
import matplotlib.pyplot as plt
df['Genre'].value_counts().plot(kind='bar')
plt.title('Customer Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')

plt.show()

# %%
# Age Distribution

plt.figure(figsize=(8, 5))
plt.hist(df['Age'], bins=10)

plt.title('Customer Age Distribution')
plt.xlabel('Age')
plt.ylabel('Number of coustomers')

plt.show()

# %%
# Annual Income Distribution Histogram plot

plt.figure(figsize=(8,5))

plt.hist(df['Annual Income (k$)'], bins=10)

plt.title('Annual Income Distribution')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Number of Customers')

plt.show()

# %%
#Spending Score Distribution Histogram Plot

plt.figure(figsize=(8,5))
plt.hist(df['Spending Score (1-100)'], bins=10)

plt.title('Spending Score Distribution')
plt.xlabel('Spending Score')
plt.ylabel('Number of Customers')

plt.show()

# %%
x = df[['Annual Income (k$)','Spending Score (1-100)']]
x.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []

for k in range(1,11):
    kmeans = KMeans(n_clusters=k,random_state=42,n_init=10)
    kmeans.fit(x)

inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), inertia, marker='o')

plt.title('Elbow Method')
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Inertia')

plt.show()

# %%
#Elbow Graph
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []

for k in range(1,11):
    kmeans = KMeans(n_clusters=k,
random_state=42,n_init=10)
    kmeans.fit(x)

    inertia.append(kmeans.inertia_)
    print(inertia)

plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), inertia, marker='o')

plt.title('Elbow Method')
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Inertia')
plt.xticks(range(1,11))

plt.show()
# Out:
# [269981.28]
# [269981.28, 181363.59595959593]
# [269981.28, 181363.59595959593, 106348.37306211122]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836, 44448.4554479337]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836, 44448.4554479337, 37233.814510710006]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836, 44448.4554479337, 37233.814510710006, 30241.34361793658]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836, 44448.4554479337, 37233.814510710006, 30241.34361793658, 25036.417604033988]
# [269981.28, 181363.59595959593, 106348.37306211122, 73679.78903948836, 44448.4554479337, 37233.814510710006, 30241.34361793658, 25036.417604033988, 21916.79478984373]
# ...

# %%
#K-Means Clustering 
kmeans = KMeans(n_clusters=5,random_state=42, n_init=10)

df['Cluster'] = kmeans.fit_predict(x)
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        4
# 1        2
# 2        4
# 3        2
# 4        4

# %%
# 5 Customer Clusters Visulization
plt.figure(figsize=(10,6))

plt.scatter(
    df['Annual Income (k$)'],
    df['Spending Score (1-100)'],
    c=df['Cluster'],
    s=80
)

plt.title('Customer Segmentation Using K-Means')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')

plt.show()

# %%
#How Many cluster's  in Customers
cluster_counts = df['Cluster'].value_counts().sort_index()

print("Customers in each Cluster:")
print(cluster_counts)
# Out:
# Customers in each Cluster:
# Cluster
# 0    81
# 1    39
# 2    22
# 3    35
# 4    23
# Name: count, dtype: int64

# %%
#Every Cluster Average Income & Spending Score
cluster_summary = df.groupby('Cluster')[['Annual Income (k$)','Spending Score (1-100)']].mean()

print(cluster_summary)
# Out:
#          Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0                 55.296296               49.518519
# 1                 86.538462               82.128205
# 2                 25.727273               79.363636
# 3                 88.200000               17.114286
# 4                 26.304348               20.913043

# %%
cluster_counts = df['Cluster'].value_counts().sort_index()

print("Customers in Each Cluster:")

print(cluster_counts)
# Out:
# Customers in Each Cluster:
# Cluster
# 0    81
# 1    39
# 2    22
# 3    35
# 4    23
# Name: count, dtype: int64

# %%
print("Business Insights:")
print("1. Cluster 1 has high-income and high-spending customers.")
print("2. Cluster 2 has low-income but high-spending customers.")
print("3. Cluster 3 has high-income but low-spending customers.")
print("4. Cluster 4 has low-income and low-spending customers.")
print("5. Cluster 0 represents customers with medium income and medium spending.")
# Out:
# Business Insights:
# 1. Cluster 1 has high-income and high-spending customers.
# 2. Cluster 2 has low-income but high-spending customers.
# 3. Cluster 3 has high-income but low-spending customers.
# 4. Cluster 4 has low-income and low-spending customers.
# 5. Cluster 0 represents customers with medium income and medium spending.
